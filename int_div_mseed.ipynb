# %%
from obspy import read

# %%
#read data mseed
st = read("D:\Github\mseed_mas_angga\ABJI_02_2021.mseed")

# %%
# hasil sebelum integrasi
st.plot();

# %%
#i integrasi data mseed
# vel --> disp
# acc --> vel
st.integrate()
# Out:
# 14 Trace(s) in Stream:
# IA.ABJI..BHZ | 2021-01-31T23:59:59.312500Z - 2021-02-01T10:45:32.962500Z | 20.0 Hz, 774674 samples
# IA.ABJI..BHZ | 2021-02-01T12:00:09.462500Z - 2021-02-03T06:46:12.762500Z | 20.0 Hz, 3079267 samples
# IA.ABJI..BHZ | 2021-02-03T06:46:15.187500Z - 2021-02-05T04:20:57.787500Z | 20.0 Hz, 3281653 samples
# IA.ABJI..BHZ | 2021-02-05T04:21:00.187500Z - 2021-02-05T04:27:13.787500Z | 20.0 Hz, 7473 samples
# IA.ABJI..BHZ | 2021-02-05T04:27:16.187500Z - 2021-02-07T06:23:04.787500Z | 20.0 Hz, 3594973 samples
# IA.ABJI..BHZ | 2021-02-07T06:23:07.187500Z - 2021-02-16T02:02:35.237500Z | 20.0 Hz, 15239362 samples
# IA.ABJI..BHZ | 2021-02-16T03:21:30.762500Z - 2021-02-18T04:07:56.762500Z | 20.0 Hz, 3511721 samples
# IA.ABJI..BHZ | 2021-02-18T04:04:10.012500Z - 2021-02-18T04:07:56.762500Z | 20.0 Hz, 4536 samples
# IA.ABJI..BHZ | 2021-02-18T04:04:10.012500Z - 2021-02-18T04:07:56.762500Z | 20.0 Hz, 4536 samples
# ...

# %%
#hasil setelah integrasi
st.plot();

# %%
st.write("integrate.mseed", format="MSEED")
